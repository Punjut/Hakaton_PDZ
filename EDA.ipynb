# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns = 999

# %% [markdown]
# #### Загружаем очищенные данные

# %%
data19=pd.read_csv('df2019_model.csv',index_col=0)
data20=pd.read_csv('df2020_model.csv',index_col=0)
data21=pd.read_csv('df2021_model.csv',index_col=0)

data19.head(1)
# Out:
#    Наименование ДП  1, cf_likv1  1, cf_likv2  1, cf_likv3  1, cf_ob1  \
# 0                0     1.020214     0.975787     0.531527   6.094585
#
#    1, cf_ob2  1, cf_ob3  1, cf_ob4  1, cf_ob5  1, cf_rent1  1, cf_rent2  \
# 0  10.657441   6.762855  16.179594   0.713523     0.023532     0.021702
#
#    1, cf_rent3  1, сf_rent4  1, сf_rent5  1, сf_rent6  1, cf_rent7  1, cf_ru1  \
# 0     0.087606     0.325947     0.347832     1.901627     0.122779   0.052601
#
#    1, cf_ru2  1, cf_ru3  1, cf_ru4  1, cf_ru5  1, cf_ru6  1, cf_ru7  \
# 0   2.720623   0.019814   5.834154   0.634566   0.956453   0.111153
#
#    1, cf_ru8  1, cf_fu1  1, cf_fu2  1, cf_fu3  1, cf_fu4  1, cf_fu5  \
# 0   0.105925   0.268772   0.268772   0.171404   0.046069  -0.024814
#
#    1, cf_fu6  2, cf_likv1  2, cf_likv2  2, cf_likv3  2, cf_ob1  2, cf_ob2  \
# 0   0.019814     1.296635     1.226782     0.655178   7.058611  11.301351
#
#    2, cf_ob3  2, cf_ob4  2, cf_ob5  2, cf_rent1  2, cf_rent2  2, cf_rent3  \
# 0   9.348229  14.011003    0.75819     0.148945     0.184913     0.792946
#
#    2, сf_rent4  2, сf_rent5  2, сf_rent6  2, cf_rent7  2, cf_ru1  2, cf_ru2  \
# 0     2.075945     3.419407        100.0     1.045841   0.454103   1.618015
#
#    2, cf_ru3  2, cf_ru4  2, cf_ru5  2, cf_ru6  2, cf_ru7  2, cf_ru8  \
# 0   0.228773      100.0   0.827178   0.946127    0.13769   0.080178
#
#    2, cf_fu1  2, cf_fu2  2, cf_fu3  2, cf_fu4  2, cf_fu5  2, cf_fu6  \
# 0   0.381969   0.381969        0.0        0.0   0.184859   0.228773
#
#    3, cf_likv1  3, cf_likv2  3, cf_likv3  3, cf_ob1  3, cf_ob2  3, cf_ob3  \
# 0     1.238697      1.16859     0.625742   5.170578   7.443841   6.538386
#
#    3, cf_ob4  3, cf_ob5  3, cf_rent1  3, cf_rent2  3, cf_rent3  3, сf_rent4  \
# 0   9.980091   0.727897     0.122966     0.147426     0.448599     1.189552
#
#    3, сf_rent5  3, сf_rent6  3, cf_rent7  3, cf_ru1  3, cf_ru2  3, cf_ru3  \
# 0     1.682625        100.0     0.616294   0.371943   1.651707     0.1927
#
#    3, cf_ru4  3, cf_ru5  3, cf_ru6  3, cf_ru7  3, cf_ru8  3, cf_fu1  \
# 0      100.0   0.878362   0.943403   0.129559    0.08549   0.377116
#
#    3, cf_fu2  3, cf_fu3  3, cf_fu4  3, cf_fu5  3, cf_fu6  1-2, cf_likv1  \
# 0   0.377116        0.0        0.0   0.144268     0.1927       0.276421
#
#    2-3, cf_likv1  1-2, cf_likv2  2-3, cf_likv2  1-2, cf_likv3  2-3, cf_likv3  \
# 0      -0.057938       0.250995      -0.058192       0.123651      -0.029437
#
#    1-2, cf_ob1  2-3, cf_ob1  1-2, cf_ob2  2-3, cf_ob2  1-2, cf_ob3  \
# 0     0.964026    -1.888032      0.64391    -3.857511     2.585374
#
#    2-3, cf_ob3  1-2, cf_ob4  2-3, cf_ob4  1-2, cf_ob5  2-3, cf_ob5  \
# 0    -2.809843    -2.168591    -4.030912     0.044667    -0.030293
#
#    1-2, cf_rent1  2-3, cf_rent1  1-2, cf_rent2  2-3, cf_rent2  1-2, cf_rent3  \
# 0       0.125413      -0.025979       0.163211      -0.037487        0.70534
#
#    2-3, cf_rent3  1-2, сf_rent4  2-3, сf_rent4  1-2, сf_rent5  2-3, сf_rent5  \
# 0      -0.344347       1.749997      -0.886392       3.071575      -1.736782
#
#    1-2, сf_rent6  2-3, сf_rent6  1-2, cf_rent7  2-3, cf_rent7  1-2, cf_ru1  \
# 0          100.0            0.0       0.923062      -0.429547     0.401503
#
#    2-3, cf_ru1  1-2, cf_ru2  2-3, cf_ru2  1-2, cf_ru3  2-3, cf_ru3  \
# 0     -0.08216    -1.102608     0.033692     0.208959    -0.036073
#
#    1-2, cf_ru4  2-3, cf_ru4  1-2, cf_ru5  2-3, cf_ru5  1-2, cf_ru6  \
# 0        100.0          0.0     0.192611     0.051184    -0.010326
#
#    2-3, cf_ru6  1-2, cf_ru7  2-3, cf_ru7  1-2, cf_ru8  2-3, cf_ru8  \
# 0    -0.002724     0.026537    -0.008131    -0.025748     0.005312
#
#    1-2, cf_fu1  2-3, cf_fu1  1-2, cf_fu2  2-3, cf_fu2  1-2, cf_fu3  \
# 0     0.113197    -0.004853     0.113197    -0.004853    -0.171404
#
#    2-3, cf_fu3  1-2, cf_fu4  2-3, cf_fu4  1-2, cf_fu5  2-3, cf_fu5  \
# 0          0.0    -0.046069          0.0     0.209673    -0.040591
#
#    1-2, cf_fu6  2-3, cf_fu6  ПДЗ  target
# 0     0.208959    -0.036073    0       0

# %% [markdown]
# ### Определим, есть ли дубликаты или пропуски в данных

# %%
#define plotting region (1 row, 3 columns)
fig, axes = plt.subplots(1, 3)
fig.set_size_inches(14,14) 
sns.heatmap(data19.isnull(),yticklabels=False,cbar=False,cmap='viridis', ax=axes[0]).set(title='Количество пропусков в данных за 2019')
sns.heatmap(data20.isnull(),yticklabels=False,cbar=False,cmap='viridis', ax=axes[1]).set(title='Количество пропусков в данных за 2020')
sns.heatmap(data21.isnull(),yticklabels=False,cbar=False,cmap='viridis', ax=axes[2]).set(title='Количество пропусков в данных за 2021')

print(f'Количество дубликатов в данных \n за 2019 год: {data19.duplicated().sum()} \n за 2020 год: {data20.duplicated().sum()} \n за 2021 год: {data21.duplicated().sum()}')
# Out:
# Количество дубликатов в данных
#  за 2019 год: 0
#  за 2020 год: 0
#  за 2021 год: 0

# %% [markdown]
# ### Построим корреляционые матрицы для входящих факторов каждого года

# %%
sns.heatmap(data19[data19.columns[1:]].corr()).set(title='Корреляции переменных')
# Out:
# [Text(0.5, 1.0, 'Корреляции переменных')]

# %% [markdown]
# **Целевая переменная (target) слабо коррелирует c признаками за исключением коэффициента обеспеченности собственными источниками финансирования (сf_fu6),с которым есть некая положительная линейная связь**

# %% [markdown]
# ### Построим диаграммы рассеивания для определения зависимости ПДЗ от признаков

# %%
for i in data19.columns[1:]:
    plt.scatter(x = data19[i],y = data19['ПДЗ'])
    plt.xlabel(i)
    plt.ylabel('ПДЗ')
    plt.show()

# %% [markdown]
# ### Построим диаграммы рассеивания для определения зависимости целевой переменной (target) от признаков

# %% [markdown]
# **На данных графиках никакой зависимости между ПДЗ и признаками не прослеживается**

# %%
for i in data19.columns:
    plt.scatter(x = data19[i],y = data19['target'])
    plt.xlabel(i)
    plt.ylabel('target')
    plt.show()

# %% [markdown]
# **Аналогичная ситуация - на всех графиках отсутствует какой-либо паттерн поведения**

# %% [markdown]
# ### Для данных 2020 года рассмотрим влияние Фактов на целевую переменную

# %%
# Загружаем данные
data20_with_facts = pd.read_csv('data2020_with_facts.csv')
# Выделяем факты
facts = data20_with_facts[[x for x in data20_with_facts.columns if 'Факт' in x ]+['target']+['Наименование ДП']]
# Строим графики
for i in facts.columns[:-2]:
    facts.pivot_table('Наименование ДП', 'target', i, 'count').plot(kind='bar', stacked=True)
    plt.xlabel(i)
    plt.ylabel('target')
    plt.show()

# %% [markdown]
# #### Можно заметить, что большая часть Фактов не сработала или не релевантна
